# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #323031; color:#ffffff; padding:50px; -webkit-border-radius:5px; width:90%">
#
#
#
# ## Pre-Sessional Python Workshops
#
# The Python pre-sessional workshops will teach you the fundamental data types and programming techniques that are necessary to succeed on any real-world coding project/challenge. The knowledge and skills that you develop in this series will form the foundation for any data analysis, visualisation or software development project in Python.
#
# For more information about the Python pre-sessional workshops and instructions on how to install Python on your personal laptop, have a look at the [Python Pre-sessional website](https://dsl-python-presessional.streamlit.app/)
#
#
# ### Why learn Python?
#
# Python's popularity has seen a remarkable rise since its inception in the late 1990's and has established itself as one of the most widely used languages in the last 10 years. It is currently ranked as one of the top 2 programming languages by the most common programming language rankings. It is now widely used not only for Data Science, where it is leading the field together with R, but also to develop software in a more general sense. If you would like to learn more about how Python can be applied for Data Science and why it has evolved to one of the most popular programming languages overall, have a look at [this section](https://dsl-python-presessional.streamlit.app/Why_Learn_Python) of the Python
# #### Program WORDLE in Python
#
# In the final step of the Python Fundamental series, you will apply your Python skills to create WORDLE in Python. To develop Wordle in Python, you will have to combine most of the techniques that you have learned in the notebooks in a creative way.
#
# See the video below on what the final game could look like.
#
# <img src="https://www.dropbox.com/s/w8bms25985573m2/wordle.gif?raw=1" height="250px">
#
# <br>
#
# <br>
#
#
# ### Earn your Python certificate
#
# The Python Fundamentals series consists of 10 different jupyter notebooks that each teach a different topic. After having completed the series you can claim an online certificate to provide evidence of your Python skills on e.g. LinkdedIN. Please email digital.skills.lab@lse.ac.uk to claim your certificate.
#
# There are two types of certificates you can claim. Learners that have completed all Python notebooks apart from the coding challenges notebook, can claim the Python Fundamentals Attendance Badge, which provides evidence of you having completed all exercises apart from the coding challenge. Learners that have completed *at least one* of the coding challenges, can claim the Python Fundamentals Knowledge Badge. This badge provides evidence of having successfully applied the fundamental Python skills to a more complex coding project. This is to highlight that in order to solve the final coding challenges a deeper understanding of the acquired coding techniques and advanced proficiency in their practical application are required.
#
# <img src="https://www.dropbox.com/scl/fi/083kbxx6zglqvvrefybp0/progress_pf12.png?rlkey=8s5uq15bpf57w32ri8mr4nf90&raw=1" height="250px">
#
#
# ### Continue to learn Python
#
# Once you finished the Python Fundamentals series, you can progress to the Python Data Wrangling and Python Visualisation series to continue to learn with the support of our Python experts on campus or learn with the online learning platform <a href="https://dataquest.io">Dataquest</a>.

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #f2f2f2; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ## Python Fundamentals Final Coding Challenge
#
# Congratulations! You have made it through the exercises of the Python Fundamentals workshop series.
#
# You are now well prepared to face the final coding challenge. You can choose to work on the following projects:
# - Slot machine game
# - WORDLE game - basic version
# - WORDLE game - advanced version
#
# Once you have completed one of the projects and emailed your script or jupyter notebook to digital.skills.lab@lse.ac.uk, we will issue you the DSL Python Fundamentals Bronze Level Knowledge Badge.
#
# **Completing the Python Fundamentals Coding Challenge will help you improve your coding skills in various ways:**
# * *Apply your skills independently*: You have the opportunity to apply the learned concepts and skills from the Python Fundamentals notebooks in a creative and new way, which helps to reinforce and deepen your understanding of these techniques.
# * *Problem solving skills*: Working on a guided projects pushes you to break down a complex problem into smaller more manageable parts. This is a key skill for any programmer.
# * *Debugging skills*: Working on a new project, you are almost guaranteed to encounter error messages or bugs in your code. This is a phantastic learning opportunity to train your ability to identify and solve errors and bugs.
# * *Creativity*: You have focussed a lot on developing the fundamental skills of programming in Python. Now is the time to apply them in an innovative way to solve a more complex problem. Coming up with innovative ideas to solve a specific problem is another key skill for programmers.
# * *Confidence Building*: Being able to complete this programming challenge will boost your confidence and motivate you to continue to learn more complex skills and techniques and take on more complex challenges.
#
#
#
# <b>What to do when getting stuck</b>:
#     <ol>
#         <li>Ask the <b>trainer</b> if you struggle to find a solution.</li>
#         <li>Ask <a href="https://chat.openai.com/"><b>Chat-GPT</b></a> for help with the tasks.
#         <ul>
#             <li>OpenAI's ChatGPT is one of the most advanced Large Language Models (LLM) with a chatbot functionality, which means<br>
#             you can engage in a dialogue with it to ask for suggestions, examples and explanations
#             when struggling with a task.</li>
#             <li>We encourage you to not ask for solutions, but rather examples, help with errors and explanations.</li>
#             <li>We recommend to log in with your Google, Microsoft or Apple account to skip the sign up process and have direct access.</li>
#         </ul> </li>
#         <li><b>Search online:</b></li>
#         <ol>
#             <li>The answer box on the top of Google's results page</li>
#             <li><a href="https://www.stackoverflow.com">stackoverflow.com</a> (task-specific solutions)</li>
#             <li><a href="https://www.w3schools.com">w3schools.com</a> (basic python questions)</li>
#             <li><a href="https://www.realpython.com">realpython.com</a> (topic-based tutorials)</li>
#         </ol>
#     </ol>

# %% [markdown]
# <br>
#
# <br>
#
#
# ### Coding Challenge 1 - Slot Machine game
#
# In this coding challenge for the Python Fundamentals series, you will have to write a slot machine game in Python.
#
# 1. Write the `spin_reel()` function that will randomly select three symbols from the `symbols` list. You will need to use the random library randomly select elements from a list.
# 2. Write the main loop. Inside the loop, ask the player whether they want to continue to play. The loop should be terminated if the player does not want to play again. On every iteration, spin the reel and print the result using the `print_spin()` function.
# 3. Write the `evaluate_spin()` function to print a message about how much the player has won. Determine yourself how much payout the player should receive for which combination of symbols. Add the `evaluate_spin()` function to the while loop to display the payout after a spin.
# 4. You can use the `clear_output()` function from the `IPython.display` module in jupyter to clear the output of a code cell on each iteration. Place the `clear_output()` function  within your while loop, so that it will remove the previously printed slot machine result after the players input.

# %%
from IPython.display import clear_output
import random

symbols = ['🍒', '🍊', '🍋', '🔔', '⭐', 'BAR', '7']
payouts = {'🍒': 10, '🍊': 20, '🍋': 30, '🔔': 40, '⭐': 50, 'BAR': 100, '7': 50}
# Function to spin the reel
def spin_reel(symbols):
    return random.choices(symbols, k=3)

# Function to evaluate the spin and calculate the payout
def evaluate_spin(spin):
    payout = 0
    unique_symbols = set(spin)
    
    if len(unique_symbols) == 1:
        symbol = spin[0]
        payout = payouts.get(symbol, 0) * 2
        print(f"Jackpot! You've won ${payout}!")
    elif len(unique_symbols) == 2:
        print("Two of a kind!")
        for symbol in unique_symbols:
            if spin.count(symbol) == 2:
                payout = payouts.get(symbol, 0)
    else:
        print("No payout this round.")
        
    return payout

# Function to print the spin result
def print_spin(spin):
    print("+--------------+")
    print("|    CASINO    |")
    print("|--------------|")
    print(f"  {spin[0]:<3} {spin[1]:<3} {spin[2]:<3} ")
    print("|--------------|")
    print("|       [_]    |")
    print("+--------------+")

# Main game loop
def game1():
    play = True
    result = spin_reel(symbols)
    print_spin(result)
    payout = evaluate_spin(result)
    print(f"You've won ${payout}!")
    while play:
        # Ask the player if they want to play again
        play_again = input("Do you want to play again? (yes/no): ").lower()
        play = play_again == 'yes'
        # Spin the reel
        result = spin_reel(symbols)
    
        # Clear previous output before printing new output
        clear_output(wait=True)
        print_spin(result)
    
        # Evaluate the spin result and calculate payout
        payout = evaluate_spin(result) 

    print("Thanks for playing!")

# %%
game1()
# Out:
# +--------------+
# |    CASINO    |
# |--------------|
#   7   ⭐   🍒
# |--------------|
# |       [_]    |
# +--------------+
# No payout this round.
# Thanks for playing!

# %%
###old Version

# ##Feedback from Dear Michael Wiemers:
# ##The game1() function asks the user for input twice. Should only ask once.
# ##The evaluate_spin() function currently only returns a payout depending on the number of unique symbols. It should also depend on the actual symbol. As an example, 3 BAR symbols might return 100, whereas 3 7’s only return 50.
# ##Could you please update your code accordingly?

# symbols = ['🍒', '🍊', '🍋', '🔔', '⭐', 'BAR', '7']
# from IPython.display import clear_output
# import random

# # Function to spin the reel
# def spin_reel(symbols):
#     return random.choices(symbols, k=3)


# def evaluate_spin(spin):
#     # prints a statement about the payout for a specific combination of symbols
#     symbols = set(spin)
#     payout = 0
    
#     if len(symbols) == 1:
#         print("Jackpot!")
#         payout = 100
#     elif len(symbols) == 2:
#         print("Two of a kind!")
#         payout = 50
#     else:
#         print("No payout this round.")
    
#     return payout

# # Function to print the spin result
# def print_spin(spin):
#     print("+--------------+")
#     print("|    CASINO    |")
#     print("|--------------|")
#     print(f"  {spin[0]:<3} {spin[1]:<3} {spin[2]:<3} ")
#     print("|--------------|")
#     print("|       [_]    |")
#     print("+--------------+")

# # Main game loop
# def game1():
#     play = True
#     while play:
       
#         result = spin_reel(symbols)
    
#     # Clear previous output before printing new output
#         clear_output(wait=True)
#         print_spin(result)
    
#         payout = evaluate_spin(result)
#         print(f"You've won ${payout}!")
        
#         play_again = input("Do you want to play again? (yes/no): ").lower()
#         play = play_again == 'yes'
       

#         print("Thanks for playing!")
# Out:
# +--------------+
# |    CASINO    |
# |--------------|
#   ⭐   🍊   🍊
# |--------------|
# |       [_]    |
# +--------------+
# Two of a kind!
# You've won $50!
# Thanks for playing!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 61
#      54         print(f"You've won ${payout}!")
#      58         print("Thanks for playing!")
# ---> 61 game1()
#
# Cell In[21], line 45, in game1()
#      43 play = True
#      44 while play:
# ---> 45     play_again = input("Do you want to play again? (yes/no): ").lower()
#      46     play = play_again == 'yes'
#      47     result = spin_reel(symbols)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
# ...

# %% [markdown]
# <br>
#
# <br>
#
# ### Coding Challenge 2 - WORDL game - simple version
#
# We encourage you to start with the simple version of WORDLE in Python. Once you have completed this and feel ready to take on an extra challenge, move on to the advanced version.
#
# Minimal guidance on what the wordle game should do:
# - Select a word from the wordle_words.txt randomly
# - Print 6 lines of placeholder words as in the example gif
# - Prompt the user to enter a 5-letter word
# - Display a coulored version of the entered word (letter in correct position: green, letter in wrong position: yellow)
# - Terminate the game when the user entered the correct word or has run out of guesses
#
#
# <details>
#     <summary> Click here to reveal/hide more concrete tips and hints.</summary>
#
# 1. Read in the wordle_words.txt file as a list. You first have to read the file in and then split the string into a list based on linebreaks.
#
# 2. Select an element from the list randomly as the solution.
#
# 3. Create a variable for the maximum number of guesses.
#
# 4. Create a variable to keep track of how many guesses the user has guessed.
#
# 5. Create a list named `guesses` that initially consists of 6 placeholder words that should look as in the example, i.e. each placeholder should be the string: `"_ _ _ _ _ "`
#
# 6. Write a function that prints each of the six guesses in a separate line.
#
# 7. Start a while loop that:
#     - Prints the guesses.
#     - Ask the user to enter their guess.
#     - Updates the guesses list to overwrite the n-th placeholder with the entered guess.
#     - Stop the while loop if the guess is correct or the user ran out of guesses.
#
# 8. Write two separate functions that print a string in green and yellow respectively.
#     - A string preceded by the `GREEN` string will be printed in green.
#     - A string preceded by the `YELLOW` string will be printed in yellow.
#     - A string preceded by the `END` string will be printed in black.
#
# 9. Write a feedback function that uses the green and yellow function to return a coloured version of the word that the player entered.
#     - Any character from the solution that is in the correct position should be in green.
#     - Any character from the solution that is in the wrong position should be in yellow.
#     - Any character that is not part of the solution should be in black.
#
# 10. Include the feedback function in the while loop to colour the users inputs to provide hints about which letters are in the correct or wrong position.
# </details>

# %%
# On going...

# %% [markdown]
# <br>
#
# <br>
#
# ### Coding Challenge 3 - WORDL game - advanced version
#
# After having finished the basic version of the WORDLE game, you can add a few features to created a more polished version:
# * Clear the output after each time the user enters a guess
# * Test the WORDLE game using the solution "tatoo" and enter the guess "ttttt". Only the first two t's should be coloured. Adjust your `feedback` function to make the function behave that way.
# * Ask the player to enter the guess again if it contains non-letter characters or has less than or more than 5 characters.
# * Add an intro text that welcomes the player to the WORDLE game and asks them to guess the 5-letter word. This intro text should always be displayed together with all previously entered guesses of the player.
# * Print all letters of the guessed word in uppercase
# * Print the solution if the player ran out of guesses

# %%
# On going...

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#ECECEB; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ## Final task: Please give us your feedback!
#
# Upon completing the survey, **you will receive the link to the solution file**, to check how your code compares to the sample solution.
#
# In order to adapt our training to your needs and provide the most valuable learning experience for you, we depend on your feedack.
#
# We would be grateful if you could take **1 min** before the end of the workshop to get your feedback!
#
# <a href="https://lse.eu.qualtrics.com/jfe/form/SV_2beTiFd70AlRe5M?coursename=Python Fundamentals 12: Final Coding Challenge&topic=Python&link=&prog=DS&version=23-24"><b>Click here to open the survey</b></a>

# %% [markdown]
# <div style="background-color:#a373f5; color:white; border-radius:10px; padding:20px; width:95%">
#     <details>
#         <summary>
# <img src="https://www.dropbox.com/scl/fi/9bqx1gjgmbcco43q74r03/completed.png?rlkey=9jb9kdu4g406d8ubh29y4yi5e&raw=1" height=250px>
# <p>Click on the arrow to celebrate once you completed the Coding Challenge</p>
# </summary>
# <img src="https://media.tenor.com/vePpTUO_a0gAAAAC/party-cats.gif" height=300px>
# <p>Don't forget to email digital.skills.lab@lse.ac.uk this jupyter notebook with your code to claim your <b>Python Bronze Level Knowledge Badge</b>!
# </p>
#     </details>
# </div>
